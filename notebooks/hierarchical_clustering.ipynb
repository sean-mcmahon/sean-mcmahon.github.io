# %% [markdown]
# Write out sci-kit learns example, perhaps wrap the model in a class so you can easily extend with your own implementation in future
#
# Write out a short paragraph on the approach

# %% [markdown]
# For Hierarchical Clustering, you loop over the dataset and put each point into it's own cluster. You then iteratite on these clusters progressively mergeing them until 1 or K clusters exist (K being the number of desired clustered specified).
#
# There are four main ways on merging these clusters; ward, average, single linkage and complete linkage.
# Ward uses the the squared distance of clusters, and appears to be the sensible default. Average minimises the average distances between clusters. Single linked merges clusters who's single pairs are closest together, is fast but sensitive to noise. Complete linkage is the opposite f single linked lists and looks for pairs furtherest apart.
#
# There is [Sci-Kit's explanation here](https://scikit-learn.org/stable/modules/clustering.html#hierarchical-clustering), and two tutorials; [Comparing different hierarchical linkage methods on toy datasets](https://scikit-learn.org/stable/auto_examples/cluster/plot_linkage_comparison.html) and [Various Agglomerative Clustering on a 2D embedding of digits](https://scikit-learn.org/stable/auto_examples/cluster/plot_digits_linkage.html#sphx-glr-auto-examples-cluster-plot-digits-linkage-py).
#
# Found two blogs outside of Sci-Kit; one in [Towards Data Science](https://towardsdatascience.com/understanding-the-concept-of-hierarchical-clustering-technique-c6e8243758ec) and another by [Display R](https://www.displayr.com/what-is-hierarchical-clustering/#:~:text=Hierarchical%20clustering%2C%20also%20known%20as,broadly%20similar%20to%20each%20other.)
